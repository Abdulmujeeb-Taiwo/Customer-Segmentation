# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulmujeeb-Taiwo/Customer-Segmentation/blob/main/Online_Retail_Customer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget "https://archive.ics.uci.edu/static/public/502/online+retail+ii.zip"
# Out:
# --2025-01-07 00:59:18--  https://archive.ics.uci.edu/static/public/502/online+retail+ii.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail+ii.zip’
#
# online+retail+ii.zi     [               <=>  ]  43.51M  4.32MB/s    in 11s
#
# 2025-01-07 00:59:30 (3.93 MB/s) - ‘online+retail+ii.zip’ saved [45622418]

# %%
# !unzip "/content/online+retail+ii.zip"
# Out:
# Archive:  /content/online+retail+ii.zip
#  extracting: online_retail_II.xlsx

# %%
df = pd.read_excel("/content/online_retail_II.xlsx")

# %% [markdown]
# ## Data Exploratory

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %% [markdown]
# **Statistically viewing of the dataset**

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
df.describe(include='O')
# Out:
#         Invoice StockCode                         Description         Country
# count    525461    525461                              522533          525461
# unique    28816      4632                                4681              40
# top      537434    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        675      3516                                3549          485852

# %% [markdown]
# From the descriptive view of the dataset, i see that the quantity variable is incorrect, because of the negative value its shows, and also the customer ID has null values, because the count of the column is not upto the total count of the dataset

# %% [markdown]
# First i am going to correct the wrong values in quantity cloumn and removed the null from th customer ID, because, without a customer purchasing a products that means that no transaction takes place.

# %%
#Removing the null values from Customer ID
df.dropna(subset=['Customer ID'], inplace=True)

# %%
df[df['Quantity'] < 0]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %% [markdown]
# I checked why the values of Quantity colum has negative. i found the reason by checking others columns result. I see that the invoice has letter C at from of invoice, which means that the product is cancelled.

# %% [markdown]
# To solve this problem, i have to remove all the quantity values that has negative values

# %%
df = df[~df['Quantity'] < 0]
df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  407695.000000                         407695  407695.000000
# mean       13.586686  2010-07-01 10:10:10.782177792       3.294188
# min         1.000000            2009-12-01 07:45:00       0.000000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:46:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00   10953.500000
# std        96.842229                            NaN      34.756655
#
#          Customer ID
# count  407695.000000
# mean    15368.504107
# min     12346.000000
# 25%     13997.000000
# 50%     15321.000000
# 75%     16812.000000
# max     18287.000000
# std      1679.795700

# %%
df.describe(include='O')
# Out:
#         Invoice StockCode                         Description         Country
# count    407695    407695                              407695          407695
# unique    19215      4017                                4444              37
# top      500356    85123A  WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq        270      3153                                3153          370951

# %% [markdown]
# I want to comfirm the Invoice values because, the Incoice value is one of the vital variable to consider Recency of a customer, and Frequency.

# %%
df['Invoice'] = df['Invoice'].astype(str)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 525456    False
# 525457    False
# 525458    False
# 525459    False
# 525460    False
# Name: Invoice, Length: 407695, dtype: bool
